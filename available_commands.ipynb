# %%
import asyncio
from claude_agent_sdk import query, ClaudeAgentOptions, ResultMessage, SystemMessage


async def main():
    # 1. Discover available commands from the init message
    async for message in query(prompt="Hello Claude", options=ClaudeAgentOptions(max_turns=1)):
        if isinstance(message, SystemMessage) and message.subtype == "init":
            print("Available commands:", message.data["slash_commands"])


    # 3. Compact the same conversation
    async for message in query(
        prompt="/agents",
        options=ClaudeAgentOptions(continue_conversation=True, max_turns=1),
    ):
        if isinstance(message, SystemMessage) and message.subtype == "compact_boundary":
            print("Compaction completed")
            print("Pre-compaction tokens:", message.data["compact_metadata"]["pre_tokens"])
            print("Trigger:", message.data["compact_metadata"]["trigger"])
            # Example output:
            # Compaction completed
            # Pre-compaction tokens: 1842
            # Trigger: manual

# %%
await main()
# Out:
# Available commands: ['agent-reach', 'baoyu-youtube-transcript', 'better-accessibility', 'better-colors', 'better-interface', 'better-layout', 'better-typography', 'better-ui', 'better-writing', 'brainstorming', 'design-taste-frontend', 'executing-plans', 'fastmcp-server', 'find-skills', 'frontend-design', 'graphify', 'hallmark', 'handoff', 'html-mockup-consistency', 'image-to-code', 'impeccable', 'intelligent-automation-auto-recording', 'intelligent-automation-identical-env-approach', 'intelligent-automation-v2', 'intelligent-automation-v2-new', 'naagmani-app-gen', 'officecli', 'orchestrating-claude-sessions', 'redesign-existing-projects', 'security-audit', 'skill-creator', 'web-design-guidelines', 'wiki-manager', 'wren-dlt-connector', 'wren-generate-mdl', 'wren-onboarding', 'wren-usage', 'writing-plans', 'writing-skills', 'deep-research', 'jobs-audit', 'organizations-audit', 'plans-audit', 'code-review:code-review', 'claude-md-management:revise-claude-md', 'claude-md-management:clau
# ...

# %%
import asyncio
from claude_agent_sdk import ClaudeSDKClient, SystemMessage, AssistantMessage, TextBlock, ClaudeAgentOptions

# %%
LLM_MODEL = "MiniMaxAI/MiniMax-M3"
LLM_API_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IjgyNTk1NTQ1LTAyMDYtNGVlMy1hMjg3LTZhM2RiYjI2OTQzNSIsInNjb3BlIjoiaWVfbW9kZWwiLCJwcm9kdWN0IjoiSUUiLCJvd25lcklkIjoiZDNkY2VjMjgtMjQ5MS00NmU1LWI2YmYtZDcyYzg0YmRmZGEyIn0._R-wta0JXQRi3FbA7S0IXqC_sT14maRy0CwZ7kl4tM4"
LLM_BASE_URL = "http://localhost:8083/anthropic"

# %%
client = ClaudeSDKClient( options=ClaudeAgentOptions(env={
            "ANTHROPIC_API_KEY": LLM_API_KEY,
            "ANTHROPIC_BASE_URL": LLM_BASE_URL,
            "API_TIMEOUT_MS": "3000000",
            "CLAUDE_CODE_RETRY_WATCHDOG": "1",
            "CLAUDE_CODE_MAX_RETRIES": "10"
        },max_turns=1,  setting_sources = ["user"]))
await client.connect()
await client.get_server_info()
# Out:
# {'commands': [{'name': 'agent-reach',
#    'description': 'MUST USE when user wants to 调研/research/搜索/search/查/找/look up anything on the internet — e.g. 全网调研 X / 帮我调研一下 X / 查一下 X / 搜搜 X / 看看大家怎么评价 X / X 上有什么讨论 / research this topic。\nAlso MUST USE when user mentions any platform or shares any URL/链接: 小红书/xiaohongshu/xhs, Twitter/推特/X, B站/bilibili, Reddit, Facebook, Instagram, V2EX, LinkedIn/领英/招聘/求职/jobs, YouTube, GitHub code search, 小宇宙播客, 雪球/股票行情, RSS feeds, or any web URL.\n15 platforms, multi-backend routing (OpenCLI / per-platform CLIs / APIs). Zero config for 6 channels. Run `agent-reach doctor --json` to see which backend serves each platform right now.\nNOT for: 写报告/数据分析/翻译等内容加工（本 skill 只负责从互联网获取内容）； 发帖/评论/点赞等写操作；已有专门 skill 的平台（先用专门 skill）。\n【路由方式】SKILL.md 包含路由表和常用命令，复杂场景需按需阅读对应分类的 references/*.md。 分类：search / social (小红书/推特/B站/V2EX/Reddit/Facebook/Instagram) / career(LinkedIn) / dev(github) / web(网页/文章/RSS) / video(YouTube/B站/播客) / finance(雪球/股票)。 (user)',
# ...

# %%
import asyncio
from claude_agent_sdk import query, ClaudeAgentOptions, ResultMessage, SystemMessage


async def main():
    # 1. Discover available commands from the init message
    async for message in query(prompt="Hello Claude", options=ClaudeAgentOptions(max_turns=1)):
        if isinstance(message, SystemMessage) and message.subtype == "init":
            print("Available commands:", message.data["slash_commands"])

    # 2. Compaction needs existing history, so have a conversation first
    try:
        async for message in query(
            prompt="Explain what this project does",
            options=ClaudeAgentOptions(max_turns=2),
        ):
            if isinstance(message, ResultMessage) and message.subtype == "success":
                pass
    except Exception:
        pass

    # 3. Compact the same conversation
    async for message in query(
        prompt="/compact",
        options=ClaudeAgentOptions(continue_conversation=True, max_turns=1),
    ):
        if isinstance(message, SystemMessage) and message.subtype == "compact_boundary":
            print("Compaction completed")
            print("Pre-compaction tokens:", message.data["compact_metadata"]["pre_tokens"])
            print("Trigger:", message.data["compact_metadata"]["trigger"])
            # Example output:
            # Compaction completed
            # Pre-compaction tokens: 1842
            # Trigger: manual


await main()
# Out:
# Available commands: ['better-typography', 'redesign-existing-projects', 'design-taste-frontend', 'naagmani-app-gen', 'wren-onboarding', 'executing-plans', 'better-colors', 'intelligent-automation-auto-recording', 'intelligent-automation-v2', 'writing-skills', 'impeccable', 'wiki-manager', 'web-design-guidelines', 'baoyu-youtube-transcript', 'better-accessibility', 'orchestrating-claude-sessions', 'wren-generate-mdl', 'wren-dlt-connector', 'html-mockup-consistency', 'better-ui', 'intelligent-automation-v2-new', 'officecli', 'writing-plans', 'wren-usage', 'better-writing', 'hallmark', 'find-skills', 'brainstorming', 'frontend-design', 'image-to-code', 'skill-creator', 'better-layout', 'intelligent-automation-identical-env-approach', 'fastmcp-server', 'better-interface', 'graphify', 'agent-reach', 'handoff', 'security-audit', 'code-review:code-review', 'claude-md-management:revise-claude-md', 'claude-md-management:claude-md-improver', 'andrej-karpathy-skills:karpathy-guidelines', 'ponyt
# ...

# %%
client.options
# Out:
# ClaudeAgentOptions(tools=None, allowed_tools=[], system_prompt=None, mcp_servers={}, strict_mcp_config=False, permission_mode=None, continue_conversation=False, resume=None, session_id=None, max_turns=1, max_budget_usd=None, disallowed_tools=[], model=None, fallback_model=None, betas=[], permission_prompt_tool_name=None, cwd=None, cli_path=None, settings=None, add_dirs=[], env={'ANTHROPIC_API_KEY': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IjgyNTk1NTQ1LTAyMDYtNGVlMy1hMjg3LTZhM2RiYjI2OTQzNSIsInNjb3BlIjoiaWVfbW9kZWwiLCJwcm9kdWN0IjoiSUUiLCJvd25lcklkIjoiZDNkY2VjMjgtMjQ5MS00NmU1LWI2YmYtZDcyYzg0YmRmZGEyIn0._R-wta0JXQRi3FbA7S0IXqC_sT14maRy0CwZ7kl4tM4', 'ANTHROPIC_BASE_URL': 'http://localhost:8083/anthropic', 'API_TIMEOUT_MS': '3000000', 'CLAUDE_CODE_RETRY_WATCHDOG': '1', 'CLAUDE_CODE_MAX_RETRIES': '10'}, extra_args={}, max_buffer_size=None, debug_stderr=<ipykernel.iostream.OutStream object at 0x72b76d3611b0>, stderr=None, can_use_tool=None, hooks=None, user=None, include_partial_message
# ...
