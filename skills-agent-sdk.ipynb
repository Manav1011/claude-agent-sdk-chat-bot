# %%
import asyncio
from claude_agent_sdk import query, ClaudeAgentOptions, AssistantMessage, TextBlock, ResultMessage

async for message in query(
        prompt="What skills do you have?",
        options=ClaudeAgentOptions(
            setting_sources=["user"],
            skills="all",
            env={
            "ANTHROPIC_API_KEY": "97f5482590888eaa0afe9e173babd87c9abae1f5",
            "ANTHROPIC_BASE_URL": "http://localhost:8083/anthropic",
            "ANTHROPIC_MODEL": "Minimax-M2.7",
            },cwd="."),
    ):
        if isinstance(message, AssistantMessage):
            for block in message.content:
                if isinstance(block, TextBlock):
                    print(block.text)
# Out:
# [claude-code:unrecognized_model] {"model":"Minimax-M2.7","query_source":"sdk"}
# Here's what I have available via `/skill`:
#
# **Built-in Skills**
#
# | Skill | Description |
# |-------|-------------|
# | `/code-review` | Review PRs/diffs for bugs, reuse, simplification |
# | `/simplify` | Find and apply cleanup opportunities in changed code |
# | `/graphify` | Add knowledge to a knowledge graph |
# | `/brainstorming` | Explore ideas from multiple angles |
# | `/security-review` | Audit for security issues |
# | `/design-taste-frontend` | UI/UX design critique |
# | `/frontend-design` | Design and build frontend components |
# | `/image-to-code` | Convert mockups to code |
# | `/web-design-guidelines` | Web design best practices |
# | `/dataviz` | Create charts and visualizations properly |
# | `/better-*` | Specific improvements: accessibility, colors, layout, typography, UI, writing |
# | `/shadcn` | Build with shadcn/ui components |
# | `/redesign-existing-projects` | Modernize legacy projects |
# | `/officecli` | Microsoft Office file operations |
# | `/wiki-manager` | Manage wiki content |
# | `/fastmcp-server` | Build MCP servers quickly |
# | `/skill-creator` | Create new skills |
# | `/claude-api` | Anthropic API reference |
# | `/update-config` | Configure Claude Code settings |
# | `/keybindings-help` | Customize keyboard shortcuts |
# | `/loop` | Run tasks on recurring intervals |
# | `/find-skills` | Search for skills I don't have yet |
#
# **Ponytail** skills (for working with my lazy-mode rules):
# - `ponytail:help`, `ponytail:review`, `ponytail:audit`, `ponytail:debt`, `ponytail:gain`
#
# **Orchestration**
# - `/writing-plans` — write specs before building
# - `/executing-plans` — execute plans with review checkpoints
# - `/orchestrating-claude-sessions` — coordinate multiple Claude sessions
#
# Type `/skill <name>` to load any of these.

# %%
import asyncio
from pydantic import BaseModel
from claude_agent_sdk import query, ClaudeAgentOptions, ResultMessage

class Step(BaseModel):
    step_number: int
    description: str
    estimated_complexity: str  # 'low', 'medium', 'high'

class FeaturePlan(BaseModel):
    feature_name: str
    summary: str
    steps: list[Step]
    risks: list[str]

async def main():
    try:
        async for message in query(
            prompt="Plan how to add dark mode support to a React app.",
            options=ClaudeAgentOptions(
                env={
                            "ANTHROPIC_API_KEY": "97f5482590888eaa0afe9e173babd87c9abae1f5",
                            "ANTHROPIC_BASE_URL": "http://localhost:8083/anthropic",
                            "ANTHROPIC_MODEL": "Minimax-M2.7",
                            },
                output_format={
                    "type": "json_schema",
                    "schema": FeaturePlan.model_json_schema(),
                }
            ),
        ):
            print(message)
    except Exception as error:
        print(f"Session ended with an error: {error}")

await main()
# Out:
# [claude-code:unrecognized_model] {"model":"Minimax-M2.7","query_source":"sdk"}
# Feature: Dark Mode Support
# 1. [low] Define CSS custom properties for colors in :root with light defaults, then add [data-theme="dark"] block with dark overrides for each variable.
# 2. [low] On app mount, read prefers-color-scheme from matchMedia and apply. Check localStorage for stored preference—stored wins over system.
# 3. [low] Build a toggle button component that flips data-theme on <html>, persists to localStorage, and triggers re-render.
# 4. [low] Replace hardcoded color values across components with var(--bg), var(--text), var(--border), etc. defined in step 1.
